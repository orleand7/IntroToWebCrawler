# %% [markdown]
# 지난번 연습을 통해 한 페이지에 있는 텍스트를 크롤링하여 출력해 보았습니다.
#
# 이번에는 웹페이지 탐색을 자동화 함으로서 순서가 있는 여러 페이지의 기사 제목들을 크롤링 해보도록 하겠습니다.
#
# 오늘은 네이버의 정치뉴스 많이본 뉴스의 며칠분을 크롤링 해보도록 하겠습니다.
# https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=100&date=20190131
#
# 우선 코딩을 하기 전, 다음 페이지를 보는 습관을 들어두는게 좋습니다. 한번 볼까요?
#
# https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=100&date=20190130
#
# 보시다시피 이번 경우에는 뒤에 날짜가 붙어서 구분 가능한 것을 알 수 있습니다.
#
# 최근 2n일의 뉴스 제목들을 긁어 봅시다.
#
# 코딩을 시작해보죠.

# %%
#하던대로 라이브러리 부터 받아옵시다.
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#URL의 끝부분을 봐주세요 ->
base_url = 'https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=100&date=2019012{}'

for n in range (10) :
    url = base_url.format (n+1)
    webpage = urlopen(url)
    source = BeautifulSoup(webpage, 'html5lib')
    newstitles = source.find_all('div', {'class':'ranking_headline'})

#그럼 이 결과물을 이제 텍스트 파일로 출력해보겠습니다.

    for review in newstitles :
        print(review.get_text().strip())
# Out:
# [단독]김정숙 명의 文 홍은동집, 매입자는 손혜원 前보좌관
# 문 대통령, 임종석·한병도 외교특보 위촉…비서관 4명 전보 인사 …
# 김수현 “공시가 현실화 국민 공감대···서민은 타격 없게”
# 日레이더탐지음 공개에 軍 "실체 모를 기계음"…한일 '평행선'
# 국방부 "한일 레이더-위협비행 협의중단 日발표 깊은유감"(종합)
# '특검까지' 손혜원 공세 강도 높이는 野…침묵 택한 與
# 김태우 폭로에 靑 강력 반박…"조국에 충성 강요? 사실무근"
# 박지원-손혜원, '투기 vs 배신' 아이콘 '공방'…갈등 '격화'
# [줌인] '승승장구' 손혜원 탈당 승부수, 도약 vs 퇴출 갈림길
# 문대통령 "우린 구경꾼 아냐…한반도 문제 끝까지 잘되게 할 것"
# 日, 軍기밀이라더니…레이더 이어 경고음까지 '수상한 공개'
# 투기냐 공익이냐… 검찰로 공 넘긴 손혜원
# 김태우 "민정수석실 출장비 부당 수령…인사 검증 실패"(종합)
# [안성용의 정보방] 여당 내에서도 우군이 없었던 손혜원
# 정문엔 무장경찰, 하늘엔 드론… 美北, 스웨덴 숲속서 '비밀협상'
# 반성커녕 ‘좌충우돌 회견’… 불지르는 손혜원
# 목포 주민들 배신감 "孫, 동네 일으킨다 믿었는데… 제 잇속만 챙겼…
# 트럼프 "엄청난 진전에도 언론이 인정않아…김정은 만나길 고대"(종…
# 한 달 넘긴 한일 '레이더-위협비행' 갈등…출구는 어디에
# 손혜원과 목포 부동산 물색한 여성도 건물 7채 보유
# 손혜원, 前보좌관의 문대통령 사저매입 보도에 "처음 듣는다"
# 정태관 목포문화연대 대표 "나는 손혜원 의원 고발 안 했다"
# 손혜원 "부당압력 없었다"에 박물관선 "엄청난 압박"
# 경호·보안 유리한 '다낭'…北 대사관 있는 '하노이'
# 文대통령, '기초연금 부담' 지자체 호소에 "타당…제도개선 논의"
# 손혜원 탈당계 제출…野 "국정조사ㆍ특검"
# 문대통령 국정지지도 49.1%…'손혜원 의혹'에 하락 전환[리얼미터]
# 野 "의원직 사퇴해야" 일제히 비판...박지원 "손혜원이 오해"
# ...

# %% [markdown]
# 이런식으로도 뉴스기사를 크롤링 할 수 있습니다.
